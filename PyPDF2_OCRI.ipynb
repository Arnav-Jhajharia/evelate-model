# %% [markdown]
# <a href="https://colab.research.google.com/github/ayushgupta0010/CorpusAI-AI/blob/main/PyPDF2_OCRI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyocr 
# !pip install PyPDF2
# !pip install textract
# !pip install pdfminer3
# !pip install tika
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Obtaining dependency information for pyocr from https://files.pythonhosted.org/packages/91/1c/3ef6485732685ad9c938c9ebb3fad0570f58bdc54e1242cdfa40040a630e/pyocr-0.8.5-py3-none-any.whl.metadata
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.0/40.0 kB 2.1 MB/s eta 0:00:00
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: /Applications/Xcode.app/Contents/Developer/usr/bin/python3 -m pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.9/106.9 kB 3.0 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import PyPDF2
import csv
import os
import re
import pandas
import matplotlib.pyplot as plt 
import matplotlib.mlab as mlab 
import numpy
import textract

pdfList = ""
# create a list of all the PDF files in the folder and add them to the list
for filename in os.listdir('.'):
    if filename.endswith('.pdf'):
        pdfList =  pdfList + (os.path.join('.', filename)) + ";"

pdfList


from pdfminer.pdfinterp import PDFResourceManager, PDFPageInterpreter
from pdfminer.converter import TextConverter
from pdfminer.layout import LAParams
from pdfminer.pdfpage import PDFPage
from io import StringIO
from io import open

def convert_pdf_to_txt(path):
    rsrcmgr = PDFResourceManager()
    retstr = StringIO()
    codec = 'utf-8'
    laparams = LAParams()
    device = TextConverter(rsrcmgr, retstr, codec=codec, laparams=laparams)
    fp = open(path, 'rb')
    interpreter = PDFPageInterpreter(rsrcmgr, device)
    password = ""
    maxpages = 0
    caching = True
    pagenos=set()

    for page in PDFPage.get_pages(fp, pagenos, maxpages=maxpages,password=password,caching=caching, check_extractable=True):
        interpreter.process_page(page)

    text = retstr.getvalue()

    fp.close()
    device.close()
    retstr.close()
    return text

#print(text)

pdfFile = convert_pdf_to_txt(r"./19740076600.pdf")

pdfFile

# !pip install PyPDF2
import PyPDF2
pdfFileObj = open('./19740076600.pdf', 'rb')
pdfReader = PyPDF2.PdfReader(pdfFileObj)
len(pdfReader.pages)

pageObj = pdfReader.pages[0]
pageObj.extract_text()

pdfReader.metadata

pdfReader.is_encrypted

len(pdfReader.pages)

pdfFileObj = open('./19740076600.pdf', 'rb')
pdfReader = PyPDF2.PdfReader(pdfFileObj)
num_pages = len(pdfReader.pages)
count = 0
text = ""

for i in range(0, num_pages):
    pageObj = pdfReader.pages[i]
    count += 1
    text += pageObj.extract_text()

if text != "":
    text = text
else:
    text = textract.process('http://bit.ly/epo_keyword_extraction_document', method='tesseract', language='eng')

text

print(text)
# Out:
# Multiple definitions in dictionary at byte 0x1d18 for key /Length
# Multiple definitions in dictionary at byte 0x1d18 for key /Length
# Multiple definitions in dictionary at byte 0x15592 for key /Length
# Multiple definitions in dictionary at byte 0x2be41 for key /Length
# Multiple definitions in dictionary at byte 0x3eed2 for key /Length
# Multiple definitions in dictionary at byte 0x46722 for key /Length
# Multiple definitions in dictionary at byte 0x51d02 for key /Length
# Multiple definitions in dictionary at byte 0x5af6b for key /Length
# Multiple definitions in dictionary at byte 0x63ca6 for key /Length
# 4L1
# 4
# 2
# 9261
# CONSIDERATI0_S OFTHEEFFECT OFVTOL DOWNWASH
# ONTHEGROUND ENVIRONMENT
# ByThomas C.0'Bryan
# Langley Research Center
# This paper willconsider VTOL downwash from the standpoint of
# ground erosion andmovement ofobjects todetermine thepresent status
# ofthedownwash problem.
# The first problem which will beconsidered istheerosion effect
# ...

# %%
import nltk
# format the text #
print(text)
text = nltk.tokenize.word_tokenize(text)
print(text)
text = " ".join(text)
text = text.replace("\n", ".")
text = text.replace("\n", ".")

# lowercase
text = text.lower()

# remove punctuation
text = re.sub(r'[^a-zA-Z0-9\s]', ' ', text)

# tokenize document
text = text.split(".")

# remove stopwords
# from nltk.corpus import stopwords
# stop = set(stopwords.words('english'))
# text = [word for word in text if word not in stop]

pdfFileObj.close()

text
# Out:
# 4L1
# 4
# 2
# 9261
# CONSIDERATI0_S OFTHEEFFECT OFVTOL DOWNWASH
# ONTHEGROUND ENVIRONMENT
# ByThomas C.0'Bryan
# Langley Research Center
# This paper willconsider VTOL downwash from the standpoint of
# ground erosion andmovement ofobjects todetermine thepresent status
# ofthedownwash problem.
# The first problem which will beconsidered istheerosion effect
# ofthedownwash. Figure 1indicates thedynamic pressure required to
# start erosion for anumber ofground surfaces. This information isa
# s_mmary ofsmall-scale erosion tests reported inreference 1except for
# the example ofloose crushed rock at19lb/sq ft. This example was
# obtained from anincident with theVertol VZ-2 operating over anarea
# covered with loose rock which resulted indamage totheairplane. All
# data shown infigure 1were obtained with theuseofcold Jets. Since
# sodwithstands erosion atdynamic pressures upto1,000 lb/sq ft,opera-
# tion ofJetVTOL aircraft over this surface would appear feasible.
# ...

# %%
# create a word cloud from the text #

from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

stopwords = set(STOPWORDS)

wordcloud = WordCloud(
    width = 1500,
    height = 750,
    background_color = 'black',
    stopwords = stopwords
).generate(str(text))

fig = plt.figure(
    figsize = (40, 30),
    facecolor = 'k',
    edgecolor = 'k'
)

plt.imshow(wordcloud, interpolation = 'bilinear')
plt.axis('off')
plt.tight_layout(pad=0)
plt.show()

# %%
# create subsets of the text  # 
tagFinding1 = "CONTOUR"
tagFinding2 = "dimensional"
tagFinding3 = "PRESSURE"
tagFinding4 = "vtol"
tagFinding5 = "hovering"
tagFinding6 = "langley"


# check if one of your tagFindings is in the text
if tagFinding1 in text:
    print("TagFinding1 is in text")
elif tagFinding2 in text:
    print("TagFinding2 is in text")
elif tagFinding3 in text:
    print("TagFinding3 is in text")
elif tagFinding4 in text:
    print("TagFinding4 is in text")
elif tagFinding5 in text:
    print("TagFinding5 is in text")
elif tagFinding6 in text:
    print("TagFinding6 is in text")
    


plt.plot(pdfFile)
plt.show()
